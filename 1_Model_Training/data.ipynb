# %%
# !git config --global user.name "HaichuanYin"
# !git config --global user.email "ds24m042@technikum-wien.at"

# %%
repo_url = "https://github.com/jkoblmiller/sdc-final-submission.git"
# !git clone {repo_url}
# Out:
# Cloning into 'sdc-final-submission'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 27 (delta 5), reused 23 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 5.14 KiB | 1.71 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
import os
repo_name = repo_url.split('/')[-1].replace('.git', '')
os.chdir(repo_name)

# %%
# !pip install torch torchvision torchaudio
# !pip install pillow
# !pip install wandb

# %%
# !pip install efficientnet-pytorch
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16426 sha256=fb3aabcc97e716c8f93004189947d4f0393115f2b2af8a569aed1a0115ba2225
#   Stored in directory: /root/.cache/pip/wheels/9c/3f/43/e6271c7026fe08c185da2be23c98c8e87477d3db63f41f32ad
# Successfully built efficientnet-pytorch
# ...

# %%
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ds24m042 (ds24m042-fh-technikum-wien) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
WANDB_ENTITY = "ds24m042-fh-technikum-wien"
WANDB_PROJECT = "pet-breed-classifier-final"

# %%
run = wandb.init(project=WANDB_PROJECT, entity=WANDB_ENTITY, job_type="dataset-creation")
# Out:
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/sdc-final-submission/wandb/run-20251122_155619-p4igd5vi</code>
# Syncing run <strong><a href='https://wandb.ai/ds24m042-fh-technikum-wien/pet-breed-classifier-final/runs/p4igd5vi' target="_blank">devoted-rain-1</a></strong> to <a href='https://wandb.ai/ds24m042-fh-technikum-wien/pet-breed-classifier-final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ds24m042-fh-technikum-wien/pet-breed-classifier-final' target="_blank">https://wandb.ai/ds24m042-fh-technikum-wien/pet-breed-classifier-final</a>
#  View run at <a href='https://wandb.ai/ds24m042-fh-technikum-wien/pet-breed-classifier-final/runs/p4igd5vi' target="_blank">https://wandb.ai/ds24m042-fh-technikum-wien/pet-breed-classifier-final/runs/p4igd5vi</a>

# %%
raw_data_artifact = wandb.Artifact(
    name="oxford_pet_dataset",
    type="dataset",
    description="The original Oxford-IIIT Pet Dataset, unzipped."
)

# %%
print(f"current work dic: {os.getcwd()}")
# Out:
# current work dic: /content/sdc-final-submission

# %%
# !wget -P 1_Model_Training/ https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# !wget -P 1_Model_Training/ https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# Out:
# --2025-11-22 16:24:17--  https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/pets/images.tar.gz [following]
# --2025-11-22 16:24:18--  https://thor.robots.ox.ac.uk/pets/images.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 791918971 (755M) [application/octet-stream]
# Saving to: ‘1_Model_Training/images.tar.gz’
#
# images.tar.gz       100%[===================>] 755.23M  27.0MB/s    in 30s
#
# 2025-11-22 16:24:48 (25.3 MB/s) - ‘1_Model_Training/images.tar.gz’ saved [791918971/791918971]
#
# ...

# %%
# !tar -xf 1_Model_Training/images.tar.gz -C 1_Model_Training/
# !tar -xf 1_Model_Training/annotations.tar.gz -C 1_Model_Training/

# %%
# !ls -F 1_Model_Training/
# Out:
# annotations/	    dataset.py	images.tar.gz
# annotations.tar.gz  images/	train.ipynb

# %%
raw_data_artifact = wandb.Artifact(
    name="oxford_pet_dataset",
    type="dataset",
    description="The original Oxford-IIIT Pet Dataset, unzipped."
)

# %%
raw_data_artifact.add_dir("1_Model_Training/images", name="images")
raw_data_artifact.add_dir("1_Model_Training/annotations", name="annotations")
# Out:
# wandb: Adding directory to artifact (1_Model_Training/images)... Done. 8.5s
# wandb: Adding directory to artifact (1_Model_Training/annotations)... Done. 13.8s

# %%
run.log_artifact(raw_data_artifact)
# Out:
# <Artifact oxford_pet_dataset>

# %%
run.finish()


print(f"Dataset successful version to W&B: {WANDB_ENTITY}/{WANDB_PROJECT}/oxford_pet_dataset:v0")
# Out:
#  View run <strong style="color:#cdcd00">devoted-rain-1</strong> at: <a href='https://wandb.ai/ds24m042-fh-technikum-wien/pet-breed-classifier-final/runs/p4igd5vi' target="_blank">https://wandb.ai/ds24m042-fh-technikum-wien/pet-breed-classifier-final/runs/p4igd5vi</a><br> View project at: <a href='https://wandb.ai/ds24m042-fh-technikum-wien/pet-breed-classifier-final' target="_blank">https://wandb.ai/ds24m042-fh-technikum-wien/pet-breed-classifier-final</a><br>Synced 5 W&B file(s), 0 media file(s), 18499 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251122_155619-p4igd5vi/logs</code>
# Dataset successful version to W&B: ds24m042-fh-technikum-wien/pet-breed-classifier-final/oxford_pet_dataset:v0
